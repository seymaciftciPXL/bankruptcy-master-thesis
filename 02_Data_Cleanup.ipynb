# %%
# ------------------------------------------------------------
# 1. Load Data
# ------------------------------------------------------------

import pandas as pd

print("About to read the dataset...\n")

# Header-only dataframe
df_columns = pd.read_csv(
    "dataset.csv",
    nrows=0,
    encoding="latin-1"
)

print("Dataset successfully loaded.\n")
# Out:
# About to read the dataset...
#
# Dataset successfully loaded.

# %%
print(f"Columns before clean up: {df_columns.shape[1]}")

columns_to_delete = [
    'score', 'ratio12', 'ratio14', 'ratio17', 'ratio18', 'ratio19',
    'dgrmovescount', 'dgractionpubs', 'dgrstreetfails', 'dgrstreetstop',
    'dgrstreetall', 'dgrpersred', 'dgrpersgr', 'dgrpersyel', 'dgrpersblue',
    'afsluit', 'neerlegging', 'obs', 'q_laat_ratio', 'delta_aantal_dagen',
    'delta_ad_abs', 'sum_delta', 'avg_delta', 'fail_afstand', 'laatste_jaar',
    'aantal_dagen_w', 'delta_aantal_dagen_w', 'som_laat', 'som_laat_drie',
    'obser', 'laat_ratio', 'fail_dummy_drie', 'laatstejaar_laat',
    'laatstejaar_laat_dummy', 'jvo', 'dgrstreet_ratio', 'move_rate_w',
    'score_w', 'z_score_rel', 'z_score_tot', 'z_score_rel_w', 'z_score_tot_w',
    'z_addscore', 'z_add', 'total_actions', 'action_rate', 'growth',
    'trade_debt', 'fin_debt', 'total_liabilities', 'lev', 'current_ratio',
    'current_ratio_pre', 'current_dummy', 'net_income_pre', 'loss_dummy',
    'lev_w', 'size_w', 'age_w', 'growth_w', 'trade_debt_w', 'fin_debt_w',
    'laat_dummy_pre', 'laat_ratio_pre', 'laat_ord', 'avg_delta_w',
    'q_avg_delta', 'avg_delta_pre', 'laat_ratio_dummy', 'append', 'tag'
]

df_columns = df_columns.drop(columns=columns_to_delete)

print(f"Columns requested for deletion: {columns_to_delete}")
print(f"Number of total deleted columns: {len(columns_to_delete)}")
print(f"Number of columns after clean up: {df_columns.shape[1]}")
print(f"Remaining columns after clean up: {df_columns.columns.tolist()}")
# Out:
# Columns before clean up: 286
# ...
