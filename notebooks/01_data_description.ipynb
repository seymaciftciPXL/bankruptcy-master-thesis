# %%
"""
01_data_description.py

Explore the raw dataset and summarize:
- companies
- bookyears
- legal forms
- accounting schemas
- industries
- bankruptcies
- missing values

Then show the first 10 rows of the dataset.

This step is purely descriptive and does not modify the data.
"""
# Out:
# '\n01_data_description.py\n\nExplore the raw dataset and summarize:\n- companies\n- bookyears\n- legal forms\n- accounting schemas\n- industries\n- bankruptcies\n- missing values\n\nThen show the first 10 rows of the dataset.\n\nThis step is purely descriptive and does not modify the data.\n'

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from utils.load_data_raw import load_data_raw

# Load in the raw dataset
df = load_data_raw()

# %%
import pandas as pd
from utils.print_section import print_section

# ============================================================
# Dataset size
# ============================================================
print_section("Basic shape")

print(f"Rows: {len(df):,}")
print(f"Columns: {len(df.columns)}")

# ============================================================
# Number of companies
# ============================================================
print_section("Unique companies")

print(
    f"Unique VAT numbers: "
    f"{df['vat'].nunique():,}"
)

# ============================================================
# Panel structure
# ============================================================
print_section("Panel structure")

obs_per_company = df.groupby("vat").size()

print(obs_per_company.describe())

# ============================================================
# Bookyears
# ============================================================
print_section("Bookyears")

print(
    df["bookyear"]
    .value_counts()
    .sort_index()
)

# ============================================================
# Legal forms
# ============================================================
print_section("Legal forms")

print(
    df["rechtsvorm"]
    .value_counts(dropna=False)
    .head(20)
)

# ============================================================
# Accounting schemas
# ============================================================
print_section("Schema types")

print(
    df["nature"]
    .value_counts(dropna=False)
    .sort_index()
)

# ============================================================
# Industries
# ============================================================
print_section("Industries")

print(
    df["industry"]
    .value_counts(dropna=False)
    .head(20)
)

# ============================================================
# Bankruptcies
# ============================================================
print_section("Bankruptcies")

failed_companies = (
    df.loc[df["jaar_van_faling"].notna(), "vat"]
    .nunique()
)

total_companies = df["vat"].nunique()

fail_rate = (
    failed_companies / total_companies * 100
)

print(f"Unique failed companies: {failed_companies:,}")
print(f"Failure rate: {fail_rate:.2f}%")

# ============================================================
# Bankruptcy years
# ============================================================
print_section("Bankruptcy years")

print(
    df["jaar_van_faling"]
    .value_counts(dropna=False)
    .sort_index()
)

# ============================================================
# Missing value summary
# ============================================================
print_section("Missing value summary")

missing = (
    df.isna()
      .mean()
      .mul(100)
)

print(f"Columns >= 90% missing: {(missing >= 90).sum()}")
print(f"Columns >= 80% missing: {(missing >= 80).sum()}")
print(f"Columns >= 50% missing: {(missing >= 50).sum()}")

# ============================================================
# Most incomplete columns
# ============================================================
print_section("Most incomplete columns")

print(
    missing
    .sort_values(ascending=False)
    .head(30)
)

# ============================================================
# Missing rechtsvorm by schema type
# ============================================================
print_section("Missing rechtsvorm by nature")

rechtsvorm_missing = (
    df.groupby("nature")["rechtsvorm"]
      .apply(lambda x: round(x.isna().mean() * 100, 2))
)

print(rechtsvorm_missing)

# ============================================================
# Missing industry by schema type
# ============================================================
print_section("Missing industry by nature")

industry_missing = (
    df.groupby("nature")["industry"]
      .apply(lambda x: round(x.isna().mean() * 100, 2))
)

print(industry_missing)

# ============================================================
# Missing rechtsvorm by year
# ============================================================
print_section("Missing rechtsvorm by bookyear")

rechtsvorm_missing_year = (
    df.groupby("bookyear")["rechtsvorm"]
      .apply(lambda x: round(x.isna().mean() * 100, 2))
)

print(rechtsvorm_missing_year)

# ============================================================
# Missing industry by year
# ============================================================
print_section("Missing industry by bookyear")

industry_missing_year = (
    df.groupby("bookyear")["industry"]
      .apply(lambda x: round(x.isna().mean() * 100, 2))
)

print(industry_missing_year)

# ============================================================
# Missing combinations
# ============================================================
print_section("Missing rechtsvorm vs missing industry")

missing_matrix = pd.crosstab(
    df["rechtsvorm"].isna(),
    df["industry"].isna(),
    margins=True
)

print(missing_matrix)

# ============================================================
# Nature distribution for missing rechtsvorm
# ============================================================
print_section("Nature when rechtsvorm is missing")

print(
    df[df["rechtsvorm"].isna()]["nature"]
    .value_counts()
    .sort_index()
)

# ============================================================
# Nature distribution for missing industry
# ============================================================
print_section("Nature when industry is missing")

print(
    df[df["industry"].isna()]["nature"]
    .value_counts()
    .sort_index()
)

# ============================================================
# Missing rechtsvorm by year and nature (crosstab)
# ============================================================
print_section("Missing rechtsvorm by year and nature")

table = pd.crosstab(
    df["bookyear"],
    df["nature"],
    values=df["rechtsvorm"].isna(),
    aggfunc="mean"
) * 100

print(table.round(2))

# ============================================================
# Example rows with missing rechtsvorm
# ============================================================
print_section("Examples with missing rechtsvorm")

cols = [
    "vat",
    "bookyear",
    "nature",
    "industry",
    "hoofdnacebel"
]

available_cols = [
    c for c in cols
    if c in df.columns
]

print(
    df[df["rechtsvorm"].isna()][available_cols]
    .head(20)
)

# ============================================================
# Example rows with missing industry
# ============================================================
print_section("Examples with missing industry")

print(
    df[df["industry"].isna()][available_cols]
    .head(20)
)

# ============================================================
# First 10 rows to see data
# ============================================================
print_section("First 10 rows in raw dataset")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df[sorted(df.columns)].head(10).T
# Out:
# ============================================================
# Basic shape
# ============================================================
# Rows: 4,502,867
# Columns: 286
#
# ============================================================
# Unique companies
# ============================================================
# Unique VAT numbers: 564,598
#
# ============================================================
# Panel structure
# ============================================================
# count    564598.000000
# mean          7.975351
# std           3.861916
# min           1.000000
# 25%           4.000000
# 50%          10.000000
# 75%          11.000000
# max          15.000000
# dtype: float64
#
# ============================================================
# Bookyears
# ============================================================
# bookyear
# 2008         3
# 2009         5
# 2010     31784
# 2011    284926
# 2012    314612
# 2013    333952
# 2014    357660
# 2015    379375
# 2016    398733
# 2017    417623
# 2018    436562
# 2019    456311
# 2020    437892
# 2021    501596
# 2022    151269
# 2023       564
# Name: count, dtype: int64
#
# ============================================================
# Legal forms
# ============================================================
# rechtsvorm
# BVBA        2388031
# NaN         1120965
# NV           654855
# BV           162008
# CVBA          67890
# VZW           59800
# Comm.VA       16724
# Comm.V         5423
# CV (OS)        4833
# CVBA SO        3614
# BO             2814
# CVOA           2647
# VOF            2473
# IVZW           2197
# AUTOGEMB       1392
# ESV            1009
# CommV          1001
# CV              813
# BVBA SO         576
# EESV            570
# Name: count, dtype: int64
#
# ============================================================
# Schema types
# ============================================================
# nature
# 1     2393601
# 2      203881
# 3          14
# 4       63207
# 5       15866
# 7     1141246
# 8        3336
# 81     179816
# 82       9704
# 87     492196
# Name: count, dtype: int64
#
# ============================================================
# Industries
# ============================================================
# industry
# 14.0    1139048
# NaN     1120965
# 16.0     712331
# 17.0     495845
# 18.0     340437
# 15.0     234485
# 19.0     116469
# 0.0       94617
# 12.0      81583
# 11.0      70620
# 10.0      52995
# 13.0      43472
# Name: count, dtype: int64
#
# ============================================================
# Bankruptcies
# ============================================================
# Unique failed companies: 14,678
# Failure rate: 2.60%
#
# ============================================================
# Bankruptcy years
# ============================================================
# jaar_van_faling
# 2018.0      20134
# 2019.0      22370
# 2020.0      14171
# NaN       4446192
# Name: count, dtype: int64
#
# ============================================================
# Missing value summary
# ============================================================
# Columns >= 90% missing: 102
# Columns >= 80% missing: 108
# Columns >= 50% missing: 141
#
# ============================================================
# Most incomplete columns
# ============================================================
# rub5_58    100.000000
# rub793     100.000000
# rub693     100.000000
# rub1751     99.998845
# rub669      99.997957
# rub6561     99.983544
# rub6560     99.979835
# rub1750     99.976770
# rub8089     99.974727
# rub171      99.962402
# rub649      99.961491
# rub762      99.955162
# rub8485     99.948766
# rub161      99.947744
# rub283      99.943791
# rub176      99.931777
# rub9126     99.926669
# rub761      99.921939
# rub791      99.921672
# rub662      99.916209
# rub760      99.913277
# rub696      99.896399
# rub794      99.882142
# rub660      99.821736
# rub661      99.817250
# rub691      99.810254
# rub72       99.772967
# rub651      99.769036
# rub170      99.763928
# rub8475     99.738145
# dtype: float64
#
# ============================================================
# Missing rechtsvorm by nature
# ============================================================
# nature
# 1       6.38
# 2      15.58
# 3       0.00
# 4      20.41
# 5      20.67
# 7      20.65
# 8     100.00
# 81     99.91
# 82     99.77
# 87     99.96
# Name: rechtsvorm, dtype: float64
#
# ============================================================
# Missing industry by nature
# ============================================================
# nature
# 1       6.38
# 2      15.58
# 3       0.00
# 4      20.41
# 5      20.67
# 7      20.65
# 8     100.00
# 81     99.91
# 82     99.77
# 87     99.96
# Name: industry, dtype: float64
#
# ============================================================
# Missing rechtsvorm by bookyear
# ============================================================
# bookyear
# 2008    100.00
# 2009    100.00
# 2010      0.02
# 2011      0.00
# 2012      0.01
# 2013      0.01
# 2014      0.01
# 2015      0.03
# 2016      0.08
# 2017      0.22
# 2018      0.71
# 2019      8.84
# 2020     96.52
# 2021    100.00
# 2022    100.00
# 2023    100.00
# Name: rechtsvorm, dtype: float64
#
# ============================================================
# Missing industry by bookyear
# ============================================================
# bookyear
# 2008    100.00
# 2009    100.00
# 2010      0.02
# 2011      0.00
# 2012      0.01
# 2013      0.01
# 2014      0.01
# 2015      0.03
# 2016      0.08
# 2017      0.22
# 2018      0.71
# 2019      8.84
# 2020     96.52
# 2021    100.00
# 2022    100.00
# 2023    100.00
# Name: industry, dtype: float64
#
# ============================================================
# Missing rechtsvorm vs missing industry
# ============================================================
# industry      False     True      All
# rechtsvorm
# False       3381902        0  3381902
# True              0  1120965  1120965
# All         3381902  1120965  4502867
#
# ============================================================
# Nature when rechtsvorm is missing
# ============================================================
# nature
# 1     152715
# 2      31764
# 4      12900
# 5       3280
# 7     235632
# 8       3336
# 81    179655
# 82      9682
# 87    492001
# Name: count, dtype: int64
#
# ============================================================
# Nature when industry is missing
# ============================================================
# nature
# 1     152715
# 2      31764
# 4      12900
# 5       3280
# 7     235632
# 8       3336
# 81    179655
# 82      9682
# 87    492001
# Name: count, dtype: int64
#
# ============================================================
# Missing rechtsvorm by year and nature
# ============================================================
# nature        1       2    3       4       5       7      8       81      82  \
# bookyear
# 2008      100.00     NaN  NaN     NaN     NaN     NaN    NaN     NaN     NaN
# 2009      100.00     NaN  NaN     NaN     NaN     NaN    NaN     NaN     NaN
# 2010        0.02    0.00  NaN    0.00    0.00     NaN    NaN     NaN     NaN
# 2011        0.00    0.00  NaN    0.00    0.00     NaN    NaN     NaN     NaN
# 2012        0.01    0.00  NaN    0.00    0.08     NaN    NaN     NaN     NaN
# 2013        0.01    0.01  NaN    0.06    0.08     NaN    NaN     NaN     NaN
# 2014        0.01    0.00  NaN    0.07    0.07    0.00    NaN     NaN     NaN
# 2015        0.03    0.00  0.0    0.11    0.07    0.13    NaN     NaN     NaN
# 2016        0.08    0.04  NaN    0.20    0.14    0.09    NaN     NaN     NaN
# 2017        0.22    0.12  NaN    0.46    0.26    0.23    NaN     NaN     NaN
# 2018        0.59    0.45  NaN    1.27    0.52    0.78    NaN     NaN     NaN
# 2019        7.44    6.06  NaN    9.91    6.79    9.26  100.0   77.53   82.00
# 2020       92.25   93.83  NaN   99.25   99.61   92.86  100.0   99.91   99.64
# 2021      100.00  100.00  NaN  100.00  100.00  100.00  100.0  100.00  100.00
# 2022      100.00  100.00  NaN  100.00  100.00  100.00  100.0  100.00  100.00
# 2023      100.00  100.00  NaN  100.00  100.00  100.00  100.0  100.00  100.00
#
# nature        87
# bookyear
# 2008         NaN
# 2009         NaN
# 2010         NaN
# 2011         NaN
# 2012         NaN
# 2013         NaN
# 2014         NaN
# 2015         NaN
# 2016         NaN
# 2017         NaN
# 2018      100.00
# 2019       88.26
# 2020       99.97
# 2021      100.00
# 2022      100.00
# 2023      100.00
#
# ============================================================
# Examples with missing rechtsvorm
# ============================================================
#           vat  bookyear  nature  industry  hoofdnacebel
# 0   200065765      2020       2       NaN           NaN
# 1   200068636      2020       2       NaN           NaN
# 2   200068636      2021       2       NaN           NaN
# 3   200305493      2020      82       NaN           NaN
# 4   200305493      2021      82       NaN           NaN
# 5   200362210      2019       2       NaN           NaN
# 6   200362210      2020      82       NaN           NaN
# 7   200362210      2021      82       NaN           NaN
# 8   200362408      2021       2       NaN           NaN
# 9   200762878      2020      82       NaN           NaN
# 10  200762878      2021      82       NaN           NaN
# 11  200881951      2020       2       NaN           NaN
# 12  200881951      2021       2       NaN           NaN
# 13  200952524      2020       1       NaN           NaN
# 14  201105843      2020      82       NaN           NaN
# 15  201105843      2021      82       NaN           NaN
# 16  201107526      2020       7       NaN           NaN
# 17  201107526      2021       7       NaN           NaN
# 18  201107922      2020      82       NaN           NaN
# 19  201107922      2021      81       NaN           NaN
#
# ============================================================
# Examples with missing industry
# ============================================================
#           vat  bookyear  nature  industry  hoofdnacebel
# 0   200065765      2020       2       NaN           NaN
# 1   200068636      2020       2       NaN           NaN
# 2   200068636      2021       2       NaN           NaN
# 3   200305493      2020      82       NaN           NaN
# 4   200305493      2021      82       NaN           NaN
# 5   200362210      2019       2       NaN           NaN
# 6   200362210      2020      82       NaN           NaN
# 7   200362210      2021      82       NaN           NaN
# 8   200362408      2021       2       NaN           NaN
# 9   200762878      2020      82       NaN           NaN
# 10  200762878      2021      82       NaN           NaN
# 11  200881951      2020       2       NaN           NaN
# 12  200881951      2021       2       NaN           NaN
# 13  200952524      2020       1       NaN           NaN
# 14  201105843      2020      82       NaN           NaN
# 15  201105843      2021      82       NaN           NaN
# 16  201107526      2020       7       NaN           NaN
# 17  201107526      2021       7       NaN           NaN
# 18  201107922      2020      82       NaN           NaN
# 19  201107922      2021      81       NaN           NaN
#
# ============================================================
# First 10 rows in raw dataset
# ============================================================
#                                 0              1              2          3  \
# Rub16                         NaN            NaN            NaN        NaN
# aantal_dagen                  NaN            NaN            NaN        NaN
# aantal_dagen_w                NaN            NaN            NaN        NaN
# action_rate                   NaN            NaN            NaN        NaN
# afsluit                       NaN            NaN            NaN        NaN
# age                           NaN            NaN            NaN        NaN
# age_in_years                  NaN            NaN            NaN        NaN
# age_w                         NaN            NaN            NaN        NaN
# append                          1              1              1          1
# avg_delta                     NaN            NaN            NaN        NaN
# avg_delta_pre                 NaN            NaN            NaN        NaN
# avg_delta_w                   NaN            NaN            NaN        NaN
# boete_dummy                   NaN            NaN            NaN        NaN
# bookyear                     2020           2020           2021       2020
# closedate                20201231       20201231       20211231   20201231
# current_assets                NaN            NaN            NaN        NaN
# current_dummy                 NaN            NaN            NaN        NaN
# current_ratio                 NaN            NaN            NaN        NaN
# current_ratio_pre             NaN            NaN            NaN        NaN
# delta_aantal_dagen            NaN            NaN            NaN        NaN
# delta_aantal_dagen_w          NaN            NaN            NaN        NaN
# delta_ad_abs                  NaN            NaN            NaN        NaN
# deposit                  20210618       20210628       20220628   20210916
# dgractionpubs                 NaN            NaN            NaN        NaN
# dgrmovescount                 NaN            NaN            NaN        NaN
# dgrmovestreet                 NaN            NaN            NaN        NaN
# dgrpersblue                   NaN            NaN            NaN        NaN
# dgrpersgr                     NaN            NaN            NaN        NaN
# dgrpersred                    NaN            NaN            NaN        NaN
# dgrpersyel                    NaN            NaN            NaN        NaN
# dgrstreet_ratio               NaN            NaN            NaN        NaN
# dgrstreetall                  NaN            NaN            NaN        NaN
# dgrstreetfails                NaN            NaN            NaN        NaN
# dgrstreetstop                 NaN            NaN            NaN        NaN
# fail                          NaN            NaN            NaN        NaN
# fail_afstand                  NaN            NaN            NaN        NaN
# fail_dummy                    NaN            NaN            NaN        NaN
# fail_dummy_drie               NaN            NaN            NaN        NaN
# faling_datum                  NaN            NaN            NaN        NaN
# fin_debt                      NaN            NaN            NaN        NaN
# fin_debt_LT                   NaN            NaN            NaN        NaN
# fin_debt_ST                   NaN            NaN            NaN        NaN
# fin_debt_w                    NaN            NaN            NaN        NaN
# growth                        NaN            NaN            NaN        NaN
# growth_w                      NaN            NaN            NaN        NaN
# hoofdnacebel                  NaN            NaN            NaN        NaN
# industry                      NaN            NaN            NaN        NaN
# intangibles                   NaN            NaN            NaN        NaN
# jaar_van_faling               NaN            NaN            NaN        NaN
# jvo                           NaN            NaN            NaN        NaN
# laat_dummy                    NaN            NaN            NaN        NaN
# laat_dummy_pre                NaN            NaN            NaN        NaN
# laat_ord                      NaN            NaN            NaN        NaN
# laat_ratio                    NaN            NaN            NaN        NaN
# laat_ratio_dummy              NaN            NaN            NaN        NaN
# laat_ratio_pre                NaN            NaN            NaN        NaN
# laat_ratio_totaal             NaN            NaN            NaN        NaN
# laatste_jaar                  NaN            NaN            NaN        NaN
# laatstejaar_laat              NaN            NaN            NaN        NaN
# laatstejaar_laat_dummy        NaN            NaN            NaN        NaN
# lev                           NaN            NaN            NaN        NaN
# lev_w                         NaN            NaN            NaN        NaN
# loss_dummy                    NaN            NaN            NaN        NaN
# move_rate                     NaN            NaN            NaN        NaN
# move_rate_w                   NaN            NaN            NaN        NaN
# nace                       184130         136000         136000     184130
# nature                          2              2              2         82
# neerlegging                   NaN            NaN            NaN        NaN
# net_income                    NaN            NaN            NaN        NaN
# net_income_pre                NaN            NaN            NaN        NaN
# nglnbb                        NaN            NaN            NaN        NaN
# obs                           NaN            NaN            NaN        NaN
# obser                         NaN            NaN            NaN        NaN
# openingfaling                 0.0            0.0            0.0        0.0
# oprichting               19600809       19230216       19230216   19620319
# provisions                    NaN            NaN            NaN        NaN
# q_avg_delta                   NaN            NaN            NaN        NaN
# q_laat_ratio                  NaN            NaN            NaN        NaN
# ratio12                       NaN            NaN            NaN        NaN
# ratio14                       NaN            NaN            NaN        NaN
# ratio17                       NaN            NaN            NaN        NaN
# ratio18                       NaN            NaN            NaN        NaN
# ratio19                       NaN            NaN            NaN        NaN
# rechtsvorm                    NaN            NaN            NaN        NaN
# rub10                     1763550    614127587,5      614305000          0
# rub100                        NaN            NaN            NaN        NaN
# rub101                        NaN            NaN            NaN        NaN
# rub10_15                      NaN            NaN            NaN        NaN
# rub10_49                 78782158  3155404312,41  3188548498,59   64485450
# rub11                      793433    23686901,55    23336711,79          0
# rub12                        2940   582322470,57   575038074,06          0
# rub13                     2554829   326539674,84   363743363,01    5821210
# rub130                        NaN            NaN            NaN        NaN
# rub1303                       NaN            NaN            NaN        NaN
# rub131                        NaN            NaN            NaN        NaN
# rub132                        NaN            NaN            NaN        NaN
# rub1323                       NaN            NaN            NaN        NaN
# rub133                        NaN            NaN            NaN        NaN
# rub1333                       NaN            NaN            NaN        NaN
# rub1343                       NaN            NaN            NaN        NaN
# rub14                     9424540              0              0    2693743
# rub15                           0   139967293,69   155172909,49      25000
# rub1501                       NaN            NaN            NaN        NaN
# rub1511                       NaN            NaN            NaN        NaN
# rub16                    14580380    21079932,93    17760820,97    2634957
# rub160                        NaN            NaN            NaN        NaN
# rub160_5                      NaN            NaN            NaN        NaN
# rub161                        NaN            NaN            NaN        NaN
# rub162                        NaN            NaN            NaN        NaN
# rub163_5                      NaN            NaN            NaN        NaN
# rub168                        NaN            NaN            NaN        NaN
# rub17                    42117620  1112885826,43  1111781838,59     367838
# rub170                        NaN            NaN            NaN        NaN
# rub170_4                 42117620  1054970177,34  1061177979,29     367838
# rub171                        NaN            NaN            NaN        NaN
# rub172                        NaN            NaN            NaN        NaN
# rub172_3                 30464261              0              0          0
# rub173                        NaN            NaN            NaN        NaN
# rub174                        NaN            NaN            NaN        NaN
# rub174_0                 11653359              0              0     367838
# rub175                          0              0              0          0
# rub1750                       NaN            NaN            NaN        NaN
# rub1751                       NaN            NaN            NaN        NaN
# rub176                        NaN            NaN            NaN        NaN
# rub178_9                      NaN            NaN            NaN        NaN
# rub17_49                 49662486  1447680451,33  1439191619,27   26386528
# rub20                         NaN            NaN            NaN        NaN
# rub20_28                      NaN            NaN            NaN        NaN
# rub20_58                 78782159  3155404312,41  3188548498,59   64485450
# rub21                         NaN            NaN            NaN        NaN
# rub21_28                  2153917   2840588646,3  2910626130,77    5418688
# rub22                         NaN            NaN            NaN        NaN
# rub22_27                  2132506  2819205195,29  2888045248,46    5251325
# rub23                         NaN            NaN            NaN        NaN
# rub24                         NaN            NaN            NaN        NaN
# rub25                         NaN            NaN            NaN        NaN
# rub26                         NaN            NaN            NaN        NaN
# rub27                         NaN            NaN            NaN        NaN
# rub28                       10625     4454958,54     4451643,54     162070
# rub280                        NaN            NaN            NaN        NaN
# rub281                        NaN            NaN            NaN        NaN
# rub282                        NaN            NaN            NaN        NaN
# rub282_3                      NaN            NaN            NaN        NaN
# rub283                        NaN            NaN            NaN        NaN
# rub284                        NaN            NaN            NaN        NaN
# rub284_8                      NaN            NaN            NaN        NaN
# rub285_8                      NaN            NaN            NaN        NaN
# rub29                           0              0              0     129380
# rub290                          0              0              0          0
# rub291                          0              0              0     129380
# rub29_58                 76628242   314815666,11   277922367,82   59066761
# rub3                     35017350      9715942,5    10652468,76   46723633
# rub30_36                 35017350     5694334,73     5977046,34          0
# rub37                           0     4021607,77     4675422,42   46723633
# rub40                     5032257   113722195,77    90918154,11    7323936
# rub40_41                      NaN            NaN            NaN        NaN
# rub41                         NaN            NaN            NaN        NaN
# rub42                     5306009     48276047,5    80333436,89      21638
# rub42_48                  7047271   319887483,36   311442976,88   25987003
# rub43                           0       81000000       42000000   15500000
# rub430_8                        0       81000000       42000000   15500000
# rub439                          0              0              0          0
# rub44                      895990     54468192,7    41697176,51     505416
# rub440_4                      NaN            NaN            NaN        NaN
# rub441                        NaN            NaN            NaN        NaN
# rub45                         NaN            NaN            NaN        NaN
# rub450_3                      NaN            NaN            NaN        NaN
# rub454_9                      NaN            NaN            NaN        NaN
# rub46                         NaN            NaN            NaN        NaN
# rub47_48                      NaN            NaN            NaN        NaN
# rub490_1                   158002   135155129,13   131388220,31      59106
# rub492_3                      NaN            NaN            NaN        NaN
# rub50_53                 32199421              0              0          0
# rub51_53                 32199421              0              0          0
# rub54_58                  3347743    27514080,46     4509959,79    4791411
# rub5_58                       NaN            NaN            NaN        NaN
# rub60                         NaN            NaN            NaN        NaN
# rub600_8                      NaN            NaN            NaN        NaN
# rub609                        NaN            NaN            NaN        NaN
# rub60_64                      NaN            NaN            NaN        NaN
# rub61                         NaN            NaN            NaN        NaN
# rub62                         NaN            NaN            NaN        NaN
# rub630                     130036    71218414,77     74976873,5     273792
# rub631_4                      NaN            NaN            NaN        NaN
# rub635_7                      NaN            NaN            NaN        NaN
# rub640_8                      NaN            NaN            NaN        NaN
# rub649                        NaN            NaN            NaN        NaN
# rub65                      519177    32435486,74    31580591,74      48393
# rub650                        NaN            NaN            NaN        NaN
# rub651                        NaN            NaN            NaN        NaN
# rub652_9                      NaN            NaN            NaN        NaN
# rub653                        NaN            NaN            NaN        NaN
# rub656                        NaN            NaN            NaN        NaN
# rub6560                       NaN            NaN            NaN        NaN
# rub6561                       NaN            NaN            NaN        NaN
# rub66                         504      4213210,6     4683566,14          0
# rub660                        NaN            NaN            NaN        NaN
# rub661                        NaN            NaN            NaN        NaN
# rub662                        NaN            NaN            NaN        NaN
# rub663                        NaN            NaN            NaN        NaN
# rub664_8                      NaN            NaN            NaN        NaN
# rub669                        NaN            NaN            NaN        NaN
# rub670_3                      NaN            NaN            NaN        NaN
# rub67_77                    90096      402367,52      156022,69      47851
# rub680                        NaN            NaN            NaN        NaN
# rub689                        NaN            NaN            NaN        NaN
# rub691                        NaN            NaN            NaN        NaN
# rub691_2                      NaN            NaN            NaN        NaN
# rub6920                       NaN            NaN            NaN        NaN
# rub6921                       NaN            NaN            NaN        NaN
# rub693                        NaN            NaN            NaN        NaN
# rub694                        NaN            NaN            NaN        NaN
# rub694_6                      NaN            NaN            NaN        NaN
# rub695                        NaN            NaN            NaN        NaN
# rub696                        NaN            NaN            NaN        NaN
# rub70                     5439089   438402158,13   426720744,23   26774623
# rub70_74                      NaN            NaN            NaN        NaN
# rub71                         NaN            NaN            NaN        NaN
# rub72                         NaN            NaN            NaN        NaN
# rub74                         NaN            NaN            NaN        NaN
# rub75                       18021     4812536,97     4702033,42      16360
# rub750                        NaN            NaN            NaN        NaN
# rub751                        NaN            NaN            NaN        NaN
# rub752_9                      NaN            NaN            NaN        NaN
# rub76                           0     2798126,65      211058,83          0
# rub760                        NaN            NaN            NaN        NaN
# rub761                        NaN            NaN            NaN        NaN
# rub762                        NaN            NaN            NaN        NaN
# rub763                        NaN            NaN            NaN        NaN
# rub764_9                      NaN            NaN            NaN        NaN
# rub77                         NaN            NaN            NaN        NaN
# rub780                        NaN            NaN            NaN        NaN
# rub789                        NaN            NaN            NaN        NaN
# rub791                        NaN            NaN            NaN        NaN
# rub791_2                      NaN            NaN            NaN        NaN
# rub792                        NaN            NaN            NaN        NaN
# rub793                        NaN            NaN            NaN        NaN
# rub794                        NaN            NaN            NaN        NaN
# rub8079                       NaN            NaN            NaN        NaN
# rub8089                       NaN            NaN            NaN        NaN
# rub8279                       NaN            NaN            NaN        NaN
# rub8289                       NaN            NaN            NaN        NaN
# rub8475                       NaN            NaN            NaN        NaN
# rub8485                       NaN            NaN            NaN        NaN
# rub9072                       NaN            NaN            NaN        NaN
# rub9076                       NaN            NaN            NaN        NaN
# rub9087                       NaN            NaN            NaN        NaN
# rub9125                       NaN            NaN            NaN        NaN
# rub9126                       NaN            NaN            NaN        NaN
# rub9134                       NaN            NaN            NaN        NaN
# rub9900                         0              0              0          0
# rub9901                    615472    61099803,15    61426379,98    2630017
# rub9902                         0              0              0          0
# rub9903                    113812    32061769,43    30075314,35    2597984
# rub9904                     23716    31659401,91    29919291,66    2550134
# rub9905                       NaN            NaN            NaN        NaN
# rub9906                       NaN            NaN            NaN        NaN
# score                        -9.0           -7.0           -7.0       -7.0
# score_w                       NaN            NaN            NaN        NaN
# size                          NaN            NaN            NaN        NaN
# size_w                        NaN            NaN            NaN        NaN
# som_laat                      NaN            NaN            NaN        NaN
# som_laat_drie                 NaN            NaN            NaN        NaN
# som_laat_totaal               NaN            NaN            NaN        NaN
# st_debt                       NaN            NaN            NaN        NaN
# startdate                20200101       20200101       20210101   20200101
# stopdatum                     0.0            0.0            0.0        0.0
# stopreden                     NaN            NaN            NaN        NaN
# sum_delta                     NaN            NaN            NaN        NaN
# ta                            NaN            NaN            NaN        NaN
# tag                             1              1              1          1
# total_actions                 NaN            NaN            NaN        NaN
# total_debt                    NaN            NaN            NaN        NaN
# total_liabilities             NaN            NaN            NaN        NaN
# total_moves                   NaN            NaN            NaN        NaN
# trade_debt                    NaN            NaN            NaN        NaN
# trade_debt_LT                 NaN            NaN            NaN        NaN
# trade_debt_ST                 NaN            NaN            NaN        NaN
# trade_debt_w                  NaN            NaN            NaN        NaN
# vat                     200065765      200068636      200068636  200305493
# z_add                         NaN            NaN            NaN        NaN
# z_addscore                    NaN            NaN            NaN        NaN
# z_score_rel                   NaN            NaN            NaN        NaN
# z_score_rel_w                 NaN            NaN            NaN        NaN
# z_score_tot                   NaN            NaN            NaN        NaN
# z_score_tot_w                 NaN            NaN            NaN        NaN
#
#                                   4          5          6             7  \
# Rub16                           NaN        NaN        NaN           NaN
# aantal_dagen                    NaN        NaN        NaN           NaN
# aantal_dagen_w                  NaN        NaN        NaN           NaN
# action_rate                     NaN        NaN        NaN           NaN
# afsluit                         NaN        NaN        NaN           NaN
# age                             NaN        NaN        NaN           NaN
# age_in_years                    NaN        NaN        NaN           NaN
# age_w                           NaN        NaN        NaN           NaN
# append                            1          1          1             1
# avg_delta                       NaN        NaN        NaN           NaN
# avg_delta_pre                   NaN        NaN        NaN           NaN
# avg_delta_w                     NaN        NaN        NaN           NaN
# boete_dummy                     NaN        NaN        NaN           NaN
# bookyear                       2021       2019       2020          2021
# closedate                  20211231   20191231   20201231      20211231
# current_assets                  NaN        NaN        NaN           NaN
# current_dummy                   NaN        NaN        NaN           NaN
# current_ratio                   NaN        NaN        NaN           NaN
# current_ratio_pre               NaN        NaN        NaN           NaN
# delta_aantal_dagen              NaN        NaN        NaN           NaN
# delta_aantal_dagen_w            NaN        NaN        NaN           NaN
# delta_ad_abs                    NaN        NaN        NaN           NaN
# deposit                    20220802   20201222   20210630      20230329
# dgractionpubs                   NaN        NaN        NaN           NaN
# dgrmovescount                   NaN        NaN        NaN           NaN
# dgrmovestreet                   NaN        NaN        NaN           NaN
# dgrpersblue                     NaN        NaN        NaN           NaN
# dgrpersgr                       NaN        NaN        NaN           NaN
# dgrpersred                      NaN        NaN        NaN           NaN
# dgrpersyel                      NaN        NaN        NaN           NaN
# dgrstreet_ratio                 NaN        NaN        NaN           NaN
# dgrstreetall                    NaN        NaN        NaN           NaN
# dgrstreetfails                  NaN        NaN        NaN           NaN
# dgrstreetstop                   NaN        NaN        NaN           NaN
# fail                            NaN        NaN        NaN           NaN
# fail_afstand                    NaN        NaN        NaN           NaN
# fail_dummy                      NaN        NaN        NaN           NaN
# fail_dummy_drie                 NaN        NaN        NaN           NaN
# faling_datum                    NaN        NaN        NaN           NaN
# fin_debt                        NaN        NaN        NaN           NaN
# fin_debt_LT                     NaN        NaN        NaN           NaN
# fin_debt_ST                     NaN        NaN        NaN           NaN
# fin_debt_w                      NaN        NaN        NaN           NaN
# growth                          NaN        NaN        NaN           NaN
# growth_w                        NaN        NaN        NaN           NaN
# hoofdnacebel                    NaN        NaN        NaN           NaN
# industry                        NaN        NaN        NaN           NaN
# intangibles                     NaN        NaN        NaN           NaN
# jaar_van_faling                 NaN        NaN        NaN           NaN
# jvo                             NaN        NaN        NaN           NaN
# laat_dummy                      NaN        NaN        NaN           NaN
# laat_dummy_pre                  NaN        NaN        NaN           NaN
# laat_ord                        NaN        NaN        NaN           NaN
# laat_ratio                      NaN        NaN        NaN           NaN
# laat_ratio_dummy                NaN        NaN        NaN           NaN
# laat_ratio_pre                  NaN        NaN        NaN           NaN
# laat_ratio_totaal               NaN        NaN        NaN           NaN
# laatste_jaar                    NaN        NaN        NaN           NaN
# laatstejaar_laat                NaN        NaN        NaN           NaN
# laatstejaar_laat_dummy          NaN        NaN        NaN           NaN
# lev                             NaN        NaN        NaN           NaN
# lev_w                           NaN        NaN        NaN           NaN
# loss_dummy                      NaN        NaN        NaN           NaN
# move_rate                       NaN        NaN        NaN           NaN
# move_rate_w                     NaN        NaN        NaN           NaN
# nace                         184130     137000     137000        137000
# nature                           82          2         82            82
# neerlegging                     NaN        NaN        NaN           NaN
# net_income                      NaN        NaN        NaN           NaN
# net_income_pre                  NaN        NaN        NaN           NaN
# nglnbb                          NaN        NaN        NaN           NaN
# obs                             NaN        NaN        NaN           NaN
# obser                           NaN        NaN        NaN           NaN
# openingfaling                   0.0        0.0        0.0           0.0
# oprichting                 19620319   19680226   19680226      19680226
# provisions                      NaN        NaN        NaN           NaN
# q_avg_delta                     NaN        NaN        NaN           NaN
# q_laat_ratio                    NaN        NaN        NaN           NaN
# ratio12                         NaN        NaN        NaN           NaN
# ratio14                         NaN        NaN        NaN           NaN
# ratio17                         NaN        NaN        NaN           NaN
# ratio18                         NaN        NaN        NaN           NaN
# ratio19                         NaN        NaN        NaN           NaN
# rechtsvorm                      NaN        NaN        NaN           NaN
# rub10                             0   54842644          0             0
# rub100                          NaN        NaN        NaN           NaN
# rub101                          NaN        NaN        NaN           NaN
# rub10_15                        NaN        NaN        NaN           NaN
# rub10_49                 60200921,9  479433860  495711857  496129299,09
# rub11                             0          0          0             0
# rub12                             0          0          0             0
# rub13                    5821209,91   82024081   89171339   94049115,87
# rub130                          NaN        NaN        NaN           NaN
# rub1303                         NaN        NaN        NaN           NaN
# rub131                          NaN        NaN        NaN           NaN
# rub132                          NaN        NaN        NaN           NaN
# rub1323                         NaN        NaN        NaN           NaN
# rub133                          NaN        NaN        NaN           NaN
# rub1333                         NaN        NaN        NaN           NaN
# rub1343                         NaN        NaN        NaN           NaN
# rub14                    2775101,42    7147259    4877777    4578916,05
# rub15                         12500   32991263   31248855    28493184,8
# rub1501                         NaN        NaN        NaN           NaN
# rub1511                         NaN        NaN        NaN           NaN
# rub16                    2719255,49     992076     992076    1075972,44
# rub160                          NaN        NaN        NaN           NaN
# rub160_5                        NaN        NaN        NaN           NaN
# rub161                          NaN        NaN        NaN           NaN
# rub162                          NaN        NaN        NaN           NaN
# rub163_5                        NaN        NaN        NaN           NaN
# rub168                          NaN        NaN        NaN           NaN
# rub17                        346200  234566906  251507488  239956612,96
# rub170                          NaN        NaN        NaN           NaN
# rub170_4                     346200  233190026  250130608  239956612,96
# rub171                          NaN        NaN        NaN           NaN
# rub172                          NaN        NaN        NaN           NaN
# rub172_3                          0  233190026  250130608             0
# rub173                          NaN        NaN        NaN           NaN
# rub174                          NaN        NaN        NaN           NaN
# rub174_0                          0          0          0             0
# rub175                            0          0          0             0
# rub1750                         NaN        NaN        NaN           NaN
# rub1751                         NaN        NaN        NaN           NaN
# rub176                          NaN        NaN        NaN           NaN
# rub178_9                        NaN        NaN        NaN           NaN
# rub17_49                21948841,93  301436538  312709972  309243075,46
# rub20                           NaN        NaN        NaN           NaN
# rub20_28                        NaN        NaN        NaN           NaN
# rub20_58                 60200921,9  479433860  495711857  496129299,09
# rub21                           NaN        NaN        NaN           NaN
# rub21_28                 4742431,29  347371138  338188539  339475958,74
# rub22                           NaN        NaN        NaN           NaN
# rub22_27                 4578344,69  332144002  321023348  316373982,22
# rub23                           NaN        NaN        NaN           NaN
# rub24                           NaN        NaN        NaN           NaN
# rub25                           NaN        NaN        NaN           NaN
# rub26                           NaN        NaN        NaN           NaN
# rub27                           NaN        NaN        NaN           NaN
# rub28                     162070,04   13700101   15605832   21411895,54
# rub280                          NaN        NaN        NaN           NaN
# rub281                          NaN        NaN        NaN           NaN
# rub282                          NaN        NaN        NaN           NaN
# rub282_3                        NaN        NaN        NaN           NaN
# rub283                          NaN        NaN        NaN           NaN
# rub284                          NaN        NaN        NaN           NaN
# rub284_8                        NaN        NaN        NaN           NaN
# rub285_8                        NaN        NaN        NaN           NaN
# rub29                      95262,09   22193540   19999348   20249664,52
# rub290                            0          0          0             0
# rub291                     95262,09   22193540   19999348   20249664,52
# rub29_58                55458490,61  132062723  157523318  156653340,35
# rub3                    43733638,38   50204714   57254092   62154506,49
# rub30_36                          0   50204714   57254092   62154506,49
# rub37                   43733638,38          0          0             0
# rub40                    4469899,29   19890595   24618738   26383658,59
# rub40_41                        NaN        NaN        NaN           NaN
# rub41                           NaN        NaN        NaN           NaN
# rub42                       21637,5   13653139   13709851   13491195,99
# rub42_48                19713761,92   57772351   54814820   59712099,44
# rub43                      10000000    5052369      82792       9000000
# rub430_8                   10000000    5052369      82792       9000000
# rub439                            0          0          0             0
# rub44                    1197784,61   26801045   30436998   24961451,01
# rub440_4                        NaN        NaN        NaN           NaN
# rub441                          NaN        NaN        NaN           NaN
# rub45                           NaN        NaN        NaN           NaN
# rub450_3                        NaN        NaN        NaN           NaN
# rub454_9                        NaN        NaN        NaN           NaN
# rub46                           NaN        NaN        NaN           NaN
# rub47_48                        NaN        NaN        NaN           NaN
# rub490_1                  213207,28   24879899   28212512   27417682,03
# rub492_3                        NaN        NaN        NaN           NaN
# rub50_53                          0    1798322    1865540    1952741,75
# rub51_53                          0    1798322    1865540    1952741,75
# rub54_58                 6907355,19    6204037   18720969   11356882,29
# rub5_58                         NaN        NaN        NaN           NaN
# rub60                           NaN        NaN        NaN           NaN
# rub600_8                        NaN        NaN        NaN           NaN
# rub609                          NaN        NaN        NaN           NaN
# rub60_64                        NaN        NaN        NaN           NaN
# rub61                           NaN        NaN        NaN           NaN
# rub62                           NaN        NaN        NaN           NaN
# rub630                    279294,74   23376229   23291527   23426196,68
# rub631_4                        NaN        NaN        NaN           NaN
# rub635_7                        NaN        NaN        NaN           NaN
# rub640_8                        NaN        NaN        NaN           NaN
# rub649                          NaN        NaN        NaN           NaN
# rub65                      97589,09   10949930   10545269   10100587,63
# rub650                          NaN        NaN        NaN           NaN
# rub651                          NaN        NaN        NaN           NaN
# rub652_9                        NaN        NaN        NaN           NaN
# rub653                          NaN        NaN        NaN           NaN
# rub656                          NaN        NaN        NaN           NaN
# ...
# score                          -7.0       -7.0       -7.0          -7.0
# score_w                         NaN        NaN        NaN           NaN
# size                            NaN        NaN        NaN           NaN
# size_w                          NaN        NaN        NaN           NaN
# som_laat                        NaN        NaN        NaN           NaN
# som_laat_drie                   NaN        NaN        NaN           NaN
# som_laat_totaal                 NaN        NaN        NaN           NaN
# st_debt                         NaN        NaN        NaN           NaN
# startdate                  20210101   20190101   20200101      20210101
# stopdatum                       0.0        0.0        0.0           0.0
# stopreden                       NaN        NaN        NaN           NaN
# sum_delta                       NaN        NaN        NaN           NaN
# ta                              NaN        NaN        NaN           NaN
# tag                               1          1          1             1
# total_actions                   NaN        NaN        NaN           NaN
# total_debt                      NaN        NaN        NaN           NaN
# total_liabilities               NaN        NaN        NaN           NaN
# total_moves                     NaN        NaN        NaN           NaN
# trade_debt                      NaN        NaN        NaN           NaN
# trade_debt_LT                   NaN        NaN        NaN           NaN
# trade_debt_ST                   NaN        NaN        NaN           NaN
# trade_debt_w                    NaN        NaN        NaN           NaN
# vat                       200305493  200362210  200362210     200362210
# z_add                           NaN        NaN        NaN           NaN
# z_addscore                      NaN        NaN        NaN           NaN
# z_score_rel                     NaN        NaN        NaN           NaN
# z_score_rel_w                   NaN        NaN        NaN           NaN
# z_score_tot                     NaN        NaN        NaN           NaN
# z_score_tot_w                   NaN        NaN        NaN           NaN
#
#                                  8          9
# Rub16                          NaN        NaN
# aantal_dagen                   NaN        NaN
# aantal_dagen_w                 NaN        NaN
# action_rate                    NaN        NaN
# afsluit                        NaN        NaN
# age                            NaN        NaN
# age_in_years                   NaN        NaN
# age_w                          NaN        NaN
# append                           1          1
# avg_delta                      NaN        NaN
# avg_delta_pre                  NaN        NaN
# avg_delta_w                    NaN        NaN
# boete_dummy                    NaN        NaN
# bookyear                      2021       2020
# closedate                 20211231   20201231
# current_assets                 NaN        NaN
# current_dummy                  NaN        NaN
# current_ratio                  NaN        NaN
# current_ratio_pre              NaN        NaN
# delta_aantal_dagen             NaN        NaN
# delta_aantal_dagen_w           NaN        NaN
# delta_ad_abs                   NaN        NaN
# deposit                   20220708   20210719
# dgractionpubs                  NaN        NaN
# dgrmovescount                  NaN        NaN
# dgrmovestreet                  NaN        NaN
# dgrpersblue                    NaN        NaN
# dgrpersgr                      NaN        NaN
# dgrpersred                     NaN        NaN
# dgrpersyel                     NaN        NaN
# dgrstreet_ratio                NaN        NaN
# dgrstreetall                   NaN        NaN
# dgrstreetfails                 NaN        NaN
# dgrstreetstop                  NaN        NaN
# fail                           NaN        NaN
# fail_afstand                   NaN        NaN
# fail_dummy                     NaN        NaN
# fail_dummy_drie                NaN        NaN
# faling_datum                   NaN        NaN
# fin_debt                       NaN        NaN
# fin_debt_LT                    NaN        NaN
# fin_debt_ST                    NaN        NaN
# fin_debt_w                     NaN        NaN
# growth                         NaN        NaN
# growth_w                       NaN        NaN
# hoofdnacebel                   NaN        NaN
# industry                       NaN        NaN
# intangibles                    NaN        NaN
# jaar_van_faling                NaN        NaN
# jvo                            NaN        NaN
# laat_dummy                     NaN        NaN
# laat_dummy_pre                 NaN        NaN
# laat_ord                       NaN        NaN
# laat_ratio                     NaN        NaN
# laat_ratio_dummy               NaN        NaN
# laat_ratio_pre                 NaN        NaN
# laat_ratio_totaal              NaN        NaN
# laatste_jaar                   NaN        NaN
# laatstejaar_laat               NaN        NaN
# laatstejaar_laat_dummy         NaN        NaN
# lev                            NaN        NaN
# lev_w                          NaN        NaN
# loss_dummy                     NaN        NaN
# move_rate                      NaN        NaN
# move_rate_w                    NaN        NaN
# nace                        188911     188101
# nature                           2         82
# neerlegging                    NaN        NaN
# net_income                     NaN        NaN
# net_income_pre                 NaN        NaN
# nglnbb                         NaN        NaN
# obs                            NaN        NaN
# obser                          NaN        NaN
# openingfaling                  0.0        0.0
# oprichting                19680101   19640701
# provisions                     NaN        NaN
# q_avg_delta                    NaN        NaN
# q_laat_ratio                   NaN        NaN
# ratio12                        NaN        NaN
# ratio14                        NaN        NaN
# ratio17                        NaN        NaN
# ratio18                        NaN        NaN
# ratio19                        NaN        NaN
# rechtsvorm                     NaN        NaN
# rub10                    953376,48          0
# rub100                         NaN        NaN
# rub101                         NaN        NaN
# rub10_15                       NaN        NaN
# rub10_49                2318743,35    7714262
# rub11                     30158,11          0
# rub12                            0     127115
# rub13                     95376,04    3089197
# rub130                         NaN        NaN
# rub1303                        NaN        NaN
# rub131                         NaN        NaN
# rub132                         NaN        NaN
# rub1323                        NaN        NaN
# rub133                         NaN        NaN
# rub1333                        NaN        NaN
# rub1343                        NaN        NaN
# rub14                   -207655,67          0
# rub15                     13707,25     274014
# rub1501                        NaN        NaN
# rub1511                        NaN        NaN
# rub16                            0    1650000
# rub160                         NaN        NaN
# rub160_5                       NaN        NaN
# rub161                         NaN        NaN
# rub162                         NaN        NaN
# rub163_5                       NaN        NaN
# rub168                         NaN        NaN
# rub17                            0     221379
# rub170                         NaN        NaN
# rub170_4                         0     221379
# rub171                         NaN        NaN
# rub172                         NaN        NaN
# rub172_3                         0     221379
# rub173                         NaN        NaN
# rub174                         NaN        NaN
# rub174_0                         0          0
# rub175                           0          0
# rub1750                        NaN        NaN
# rub1751                        NaN        NaN
# rub176                         NaN        NaN
# rub178_9                       NaN        NaN
# rub17_49                1433781,14    2486924
# rub20                          NaN        NaN
# rub20_28                       NaN        NaN
# rub20_58                2318743,35    7714262
# rub21                          NaN        NaN
# rub21_28                  28591,56    2923579
# rub22                          NaN        NaN
# rub22_27                  28591,56    2914413
# rub23                          NaN        NaN
# rub24                          NaN        NaN
# rub25                          NaN        NaN
# rub26                          NaN        NaN
# rub27                          NaN        NaN
# rub28                            0       9167
# rub280                         NaN        NaN
# rub281                         NaN        NaN
# rub282                         NaN        NaN
# rub282_3                       NaN        NaN
# rub283                         NaN        NaN
# rub284                         NaN        NaN
# rub284_8                       NaN        NaN
# rub285_8                       NaN        NaN
# rub29                            0          0
# rub290                           0          0
# rub291                           0          0
# rub29_58                2290151,79    4790683
# rub3                             0          0
# rub30_36                         0          0
# rub37                            0          0
# rub40                   1851150,54    1669021
# rub40_41                       NaN        NaN
# rub41                          NaN        NaN
# rub42                            0      72621
# rub42_48                 1333451,4    2265544
# rub43                       500000          0
# rub430_8                    500000          0
# rub439                           0          0
# rub44                    163423,79     317445
# rub440_4                       NaN        NaN
# rub441                         NaN        NaN
# rub45                          NaN        NaN
# rub450_3                       NaN        NaN
# rub454_9                       NaN        NaN
# rub46                          NaN        NaN
# rub47_48                       NaN        NaN
# rub490_1                  31659,55      27802
# rub492_3                       NaN        NaN
# rub50_53                         0     294186
# rub51_53                         0     294186
# rub54_58                  407341,7    2056958
# rub5_58                        NaN        NaN
# rub60                          NaN        NaN
# rub600_8                       NaN        NaN
# rub609                         NaN        NaN
# rub60_64                       NaN        NaN
# rub61                          NaN        NaN
# rub62                          NaN        NaN
# rub630                    27553,16     174894
# rub631_4                       NaN        NaN
# rub635_7                       NaN        NaN
# rub640_8                       NaN        NaN
# rub649                         NaN        NaN
# rub65                      7179,08       2390
# rub650                         NaN        NaN
# rub651                         NaN        NaN
# rub652_9                       NaN        NaN
# rub653                         NaN        NaN
# rub656                         NaN        NaN
# rub6560                        NaN        NaN
# rub6561                        NaN        NaN
# rub66                            0      23465
# rub660                         NaN        NaN
# rub661                         NaN        NaN
# rub662                         NaN        NaN
# rub663                         NaN        NaN
# rub664_8                       NaN        NaN
# rub669                         NaN        NaN
# rub670_3                       NaN        NaN
# rub67_77                    229,29       1467
# rub680                         NaN        NaN
# rub689                         NaN        NaN
# rub691                         NaN        NaN
# rub691_2                       NaN        NaN
# rub6920                        NaN        NaN
# rub6921                        NaN        NaN
# rub693                         NaN        NaN
# rub694                         NaN        NaN
# rub694_6                       NaN        NaN
# rub695                         NaN        NaN
# rub696                         NaN        NaN
# rub70                   1337534,52    2104194
# rub70_74                       NaN        NaN
# rub71                          NaN        NaN
# rub72                          NaN        NaN
# rub74                          NaN        NaN
# rub75                     11557,06      22163
# rub750                         NaN        NaN
# rub751                         NaN        NaN
# rub752_9                       NaN        NaN
# rub76                            0      41448
# rub760                         NaN        NaN
# rub761                         NaN        NaN
# rub762                         NaN        NaN
# rub763                         NaN        NaN
# rub764_9                       NaN        NaN
# rub77                          NaN        NaN
# rub780                         NaN        NaN
# rub789                         NaN        NaN
# rub791                         NaN        NaN
# rub791_2                       NaN        NaN
# rub792                         NaN        NaN
# rub793                         NaN        NaN
# rub794                         NaN        NaN
# rub8079                        NaN        NaN
# rub8089                        NaN        NaN
# rub8279                        NaN        NaN
# rub8289                        NaN        NaN
# rub8475                        NaN        NaN
# rub8485                        NaN        NaN
# rub9072                        NaN        NaN
# rub9076                        NaN        NaN
# rub9087                        NaN        NaN
# rub9125                        NaN        NaN
# rub9126                        NaN        NaN
# rub9134                        NaN        NaN
# rub9900                          0          0
# rub9901                  224881,82     -70833
# rub9902                          0          0
# rub9903                   229259,8     -33077
# rub9904                  229030,51     -34544
# rub9905                        NaN        NaN
# rub9906                        NaN        NaN
# score                        -16.0       10.0
# score_w                        NaN        NaN
# size                           NaN        NaN
# size_w                         NaN        NaN
# som_laat                       NaN        NaN
# som_laat_drie                  NaN        NaN
# som_laat_totaal                NaN        NaN
# st_debt                        NaN        NaN
# startdate                 20210101   20200101
# stopdatum                      0.0        0.0
# stopreden                      NaN        NaN
# sum_delta                      NaN        NaN
# ta                             NaN        NaN
# tag                              1          1
# total_actions                  NaN        NaN
# total_debt                     NaN        NaN
# total_liabilities              NaN        NaN
# total_moves                    NaN        NaN
# trade_debt                     NaN        NaN
# trade_debt_LT                  NaN        NaN
# trade_debt_ST                  NaN        NaN
# trade_debt_w                   NaN        NaN
# vat                      200362408  200762878
# z_add                          NaN        NaN
# z_addscore                     NaN        NaN
# z_score_rel                    NaN        NaN
# z_score_rel_w                  NaN        NaN
# z_score_tot                    NaN        NaN
# z_score_tot_w                  NaN        NaN
