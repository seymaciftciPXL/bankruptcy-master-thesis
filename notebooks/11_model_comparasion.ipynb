# %%
"""
"""

# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve().parents[0] if Path.cwd(
).name == "notebooks" else Path.cwd()
sys.path.append(str(project_root))

import pandas as pd
comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest",
        "XGBoost Financial",
        "XGBoost Financial + Behavioral",
    ],
    "ROC_AUC": [
        0.7939,
        0.7257,
        0.8438,
        0.8458,
    ],
    "Recall": [
        0.6259,
        0.0089,
        0.7074,
        0.6950,
    ],
    "Precision": [
        0.0094,
        0.0321,
        0.0107,
        0.0111,
    ],
    "F1": [
        0.0186,
        0.0139,
        0.0211,
        0.0218,
    ],
})

print(comparison)
# Out:
#                             Model  ROC_AUC  Recall  Precision      F1
# 0             Logistic Regression   0.7939  0.6259     0.0094  0.0186
# 1                   Random Forest   0.7257  0.0089     0.0321  0.0139
# 2               XGBoost Financial   0.8438  0.7074     0.0107  0.0211
# 3  XGBoost Financial + Behavioral   0.8458  0.6950     0.0111  0.0218
